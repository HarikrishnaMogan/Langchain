# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

text = ["Hi there", "Hi there"]

res = embeddings.embed_documents(text)
print(res)
# Out:
# [[-0.10393174737691879, 0.02004546858370304, 0.015061363577842712, 0.016005970537662506, -0.011926272884011269, -0.06634332984685898, 0.050125379115343094, 0.06124277040362358, 0.024816978722810745, 0.0019213886698707938, -0.008471651002764702, -0.004842348862439394, -0.04344452917575836, -0.03334446996450424, 0.029366811737418175, 0.05136564001441002, -0.01714758202433586, -0.04245493561029434, -0.16554304957389832, -0.04911312088370323, 0.016032308340072632, 0.08111681044101715, -0.12132124602794647, 0.02649860270321369, -0.04107602313160896, -0.03968743979930878, 0.006747828796505928, 0.08690182864665985, -0.06322617828845978, -0.002669305307790637, 0.021978115662932396, 0.061468929052352905, 0.020520910620689392, 0.036933526396751404, 0.03324827551841736, 0.030362818390130997, -0.045100219547748566, -0.06676852703094482, 0.03289947286248207, 0.014453673735260963, 0.0016767439665272832, -0.008043491281569004, -0.011683528311550617, 0.03398755192756653, 0.054518818855285645, -0.088
# ...

# %%
from langchain_community.document_loaders import WikipediaLoader

wiki = WikipediaLoader(query="gravity", load_max_docs=2)

wiki_data = wiki.load()
print(wiki_data)
# Out:
# [Document(metadata={'title': 'Gravity', 'summary': "In physics, gravity (from Latin  gravitas 'weight'), also known as gravitation or a gravitational interaction, is a fundamental interaction, which may be described as the effect of a field that is generated by a gravitational source such as mass.\nThe gravitational attraction between clouds of primordial hydrogen and clumps of dark matter in the early universe caused the hydrogen gas to coalesce, eventually condensing and fusing to form stars. At larger scales this resulted in galaxies and clusters, so gravity is a primary driver for the large-scale structures in the universe. Gravity has an infinite range, although its effects become weaker as objects get farther away.\nGravity is described by the general theory of relativity, proposed by Albert Einstein in 1915, which describes gravity in terms of the curvature of spacetime, caused by the uneven distribution of mass. The most extreme example of this curvature of spacetime is a bla
# ...

# %%
from langchain_chroma import Chroma
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

text_splitter = CharacterTextSplitter(chunk_size=1000,chunk_overlap=200)

texts = text_splitter.split_documents(wiki_data)
print(texts)
print(len(texts))
# Out:
# Created a chunk of size 2236, which is longer than the specified 1000
# Created a chunk of size 1889, which is longer than the specified 1000
# ...

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vector_store = Chroma(
    collection_name='gravity_collection',
    embedding_function=embeddings,
    persist_directory="./chroma_langchain_db"
)

vector_store.add_documents(documents=texts)
# Out:
# ['90d5a09c-c4f0-4a11-90a5-235d41a3e76a',
#  '489b40ed-e9f8-4fe1-a64b-26e6943aabc4',
#  '1fd84c3e-287e-4b48-89ef-407c3aec1415',
#  '3856a756-7ece-4307-8134-a86457d0e2b8',
#  'f952a0fe-49ac-4cac-bbf3-45d6d3b0f132',
#  '4221f106-70a1-4e51-8927-1121830e5be3',
#  'e51ac255-8dab-4adc-8e3e-350ac7440e4c']

# %%
res=vector_store.similarity_search("what is gravity",k=2)
print(res)
# Out:
# [Document(id='90d5a09c-c4f0-4a11-90a5-235d41a3e76a', metadata={'source': 'https://en.wikipedia.org/wiki/Gravity', 'summary': "In physics, gravity (from Latin  gravitas 'weight'), also known as gravitation or a gravitational interaction, is a fundamental interaction, which may be described as the effect of a field that is generated by a gravitational source such as mass.\nThe gravitational attraction between clouds of primordial hydrogen and clumps of dark matter in the early universe caused the hydrogen gas to coalesce, eventually condensing and fusing to form stars. At larger scales this resulted in galaxies and clusters, so gravity is a primary driver for the large-scale structures in the universe. Gravity has an infinite range, although its effects become weaker as objects get farther away.\nGravity is described by the general theory of relativity, proposed by Albert Einstein in 1915, which describes gravity in terms of the curvature of spacetime, caused by the uneven distribution
# ...

# %%
retriver = vector_store.as_retriever(search_kwargs={"k":2})

res= retriver.invoke("what is gravity?")
print(len(res))
print(res)
# Out:
# 2
# ...

# %% [markdown]
# Simple LCEL Usecase

# %%
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

model = ChatGroq(model="llama-3.3-70b-versatile")

template = """You are an assistant that answer user questions based on context given.
##question: {question}

##context:
{context}
"""

prompt = ChatPromptTemplate.from_template(template)


def formatDocs(docs):
    return "\n\n".join([d.page_content for d in docs])

# runnable parallel is applied since {} is used
chain = (
    {"context": retriver | formatDocs, "question":RunnablePassthrough()} |  
    prompt |
    model |
    StrOutputParser()
)

res = chain.invoke("what is gravity?")

print(type(res))
print(res)
# Out:
# <class 'str'>
# Gravity is a fundamental interaction in physics that is generated by a gravitational source, such as mass. It is a force that attracts two objects with mass towards each other, with the strength of the force depending on the mass of the objects and the distance between them. Gravity is responsible for the large-scale structure of the universe, including the formation of stars, galaxies, and clusters. On Earth, gravity gives weight to objects and plays a crucial role in many natural phenomena, such as surface water waves, lunar tides, and weather patterns. It is described by the general theory of relativity and can be approximated by Newton's law of universal gravitation, which states that the force of gravity (F) is proportional to the product of the masses (m and m') and inversely proportional to the square of the distance (r) between them, and is written as F = G(mm'/r^2).

# %% [markdown]
# Runnables

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableParallel, RunnableLambda

chain = RunnablePassthrough()

print(chain.invoke("hari"))
# Out:
# hari

# %%
def format_name(name):
    return name + " test"

chain = RunnablePassthrough() | RunnableLambda(format_name)

print(chain.invoke("Maths"))
# Out:
# Mathstest

# %%
chain = RunnableParallel(
    {
        "a":RunnablePassthrough(),
        "b":RunnableLambda(format_name)
    }
)

print(chain.invoke("maths"))
# Out:
# {'a': 'maths', 'b': 'mathstest'}

# %% [markdown]
# With Memory

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_core.prompts import ChatPromptTemplate

model = ChatGroq(model="llama-3.3-70b-versatile")

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("placeholder", "{history}"),
    ("human", "{input}")
])

chain = prompt | model

store = {}

def get_history(session_id: str):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="input",
    history_messages_key="history"
)

config = {"configurable": {"session_id": "123"}}

print(with_memory.invoke({"input": "Hi my name is Hari. I love AI."}, config=config).content)
print(with_memory.invoke({"input": "What is my name?"}, config=config).content)
# Out:
# Hello Hari, it's nice to meet you. That's great to hear that you're interested in AI. Artificial Intelligence is a fascinating field with endless possibilities and applications. What aspects of AI are you most interested in? Are you exploring its potential in areas like machine learning, natural language processing, or something else? I'm here to help and chat with you about AI.
# Your name is Hari.
