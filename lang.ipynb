# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
load_dotenv()
llm_model = ChatGroq(model="llama-3.3-70b-versatile")
res= llm_model.invoke("Explain why sky is blue?")
print(res)
# Out:
# content="The sky appears blue because of a phenomenon called Rayleigh scattering, which is the scattering of light by small particles or molecules in the atmosphere.\n\nHere's what happens:\n\n1. **Sunlight enters the Earth's atmosphere**: When the sun shines, it emits a broad spectrum of light, including all the colors of the visible spectrum (red, orange, yellow, green, blue, indigo, and violet).\n2. **Light encounters tiny molecules**: As sunlight travels through the atmosphere, it encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2). These molecules are much smaller than the wavelength of light.\n3. **Scattering occurs**: When light hits these small molecules, it is scattered in all directions. The amount of scattering that occurs depends on the wavelength of the light. Shorter wavelengths (like blue and violet) are scattered more than longer wavelengths (like red and orange).\n4. **Blue light is scattered the most**: Because of its shorter wavelength, blue light is scattered in all directions by the tiny molecules in the atmosphere. This is known as Rayleigh scattering, named after the British physicist Lord Rayleigh, who first described the phenomenon in the late 19th century.\n5. **Our eyes perceive the blue light**: As the scattered blue light reaches our eyes from all directions, it gives the sky its blue appearance. The color of the sky can vary depending on the time of day, atmospheric conditions, and the amount of dust and pollution in the air, but the basic principle of Rayleigh scattering remains the same.\n\nInterestingly, if the Earth's atmosphere were devoid of these tiny molecules, the sky would appear black, as the light would not be scattered and would simply travel in a straight line to our eyes.\n\nSo, to summarize: the sky appears blue because of the scattering of sunlight by tiny molecules in the atmosphere, which scatters shorter wavelengths (like blue light) more than longer wavelengths." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 391, 'prompt_tokens': 42, 'total_tokens': 433, 'completion_time': 0.81977505, 'prompt_time': 0.0036167, 'queue_time': 0.05793857, 'total_time': 0.82339175}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_eff2255fd7', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--e95d605f-c845-4c37-bf1c-b3e91489b818-0' usage_metadata={'input_tokens': 42, 'output_tokens': 391, 'total_tokens': 433}

# %% [markdown]
# Streaming

# %%
for chunk in llm_model.stream("why sky is blue?"):
    print(chunk.text, end='')
# Out:
# The sky appears blue because of a phenomenon called Rayleigh scattering, which is the scattering of light by small particles or molecules in the atmosphere. Here's a simplified explanation:
#
# 1. **Sunlight enters the Earth's atmosphere**: When sunlight enters the Earth's atmosphere, it consists of a broad spectrum of colors, including all the colors of the visible spectrum (red, orange, yellow, green, blue, indigo, and violet).
# 2. **Light encounters tiny molecules**: The sunlight encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2) in the atmosphere. These molecules are much smaller than the wavelength of light.
# 3. **Scattering occurs**: When light hits these tiny molecules, it scatters in all directions. The amount of scattering that occurs depends on the wavelength of the light. Shorter wavelengths (like blue and violet) are scattered more than longer wavelengths (like red and orange).
# 4. **Blue light is scattered more**: Because blue light has a shorter wavelength (around 450-495 nanometers), it is scattered more than other colors. This is known as Rayleigh scattering, named after the British physicist Lord Rayleigh, who first described the phenomenon in the late 19th century.
# 5. **Our eyes perceive the blue color**: As a result of this scattering, the blue light is distributed throughout the atmosphere, reaching our eyes from all directions. This is why the sky appears blue to our eyes, especially during the daytime when the sun is overhead.
#
# It's worth noting that the color of the sky can vary depending on the time of day, atmospheric conditions, and the amount of dust and pollution in the air. For example:
#
# * During sunrise and sunset, the sky can take on hues of red, orange, and pink due to the scattering of light by atmospheric particles.
# * On a cloudy day, the sky can appear gray or white due to the scattering of light by water droplets or ice crystals in the clouds.
# * In areas with high levels of air pollution, the sky can appear more hazy or brown due to the scattering of light by particles in the air.
#
# I hope that helps! Do you have any other questions about the sky or light?

# %%
messages=[("system","you are a helpful assistant that answers any questions"),
          ("human","why sky is blue?")
          ]
res = llm_model.invoke(messages)
print(res.content)
# Out:
# The sky appears blue because of a phenomenon called Rayleigh scattering, which is the scattering of light by small particles or molecules in the atmosphere.
#
# Here's a simplified explanation:
#
# 1. **Sunlight enters the Earth's atmosphere**: When sunlight enters the Earth's atmosphere, it contains all the colors of the visible spectrum, including red, orange, yellow, green, blue, indigo, and violet.
# 2. **Light encounters tiny molecules**: The sunlight encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2) in the atmosphere. These molecules are much smaller than the wavelength of light.
# 3. **Scattering occurs**: When light hits these small molecules, it scatters in all directions. The amount of scattering that occurs depends on the wavelength of the light.
# 4. **Blue light scatters more**: It turns out that shorter (blue) wavelengths are scattered more than longer (red) wavelengths. This is known as Rayleigh scattering, named after the British physicist Lord Rayleigh, who first described the phenomenon in the late 19th century.
# 5. **Blue light reaches our eyes**: As a result of this scattering, the blue light is distributed throughout the atmosphere, reaching our eyes from all directions. This is why the sky appears blue, especially during the daytime when the sun is overhead.
#
# Other factors can also influence the color of the sky, such as:
#
# * **Dust and pollution**: Tiny particles in the atmosphere can scatter light in different ways, making the sky appear more hazy or gray.
# * **Clouds**: Clouds can reflect and scatter light, changing the color of the sky.
# * **Time of day**: The color of the sky can change during sunrise and sunset, when the light has to travel through more of the atmosphere, scattering off more molecules and taking on a reddish hue.
#
# So, to summarize, the sky appears blue because of the scattering of sunlight by tiny molecules in the atmosphere, which favors shorter (blue) wavelengths over longer (red) wavelengths.

# %% [markdown]
# Prompt Templates

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("Tell me a {storyname} story about topic {topic}")
llm_prompt = prompt_template.format(storyname="a liitle girl",topic="horror")
res = llm_model.invoke(llm_prompt)
print(res)
# Out:
# content='Once upon a time, in a small, spooky town, there lived a little girl named Lily. She was a curious and brave girl, with a heart full of wonder and a mind full of questions. One dark and stormy night, Lily decided to explore the abandoned mansion on the hill, a place that was rumored to be haunted by ghosts and monsters.\n\nAs she walked up the creaky steps and pushed open the creaky door, a chill ran down her spine. The wind howled and the trees creaked, making it sound like someone was whispering her name. Lily stepped inside, her flashlight casting eerie shadows on the walls.\n\nSuddenly, she heard a strange noise, like footsteps coming from the floor above. Lily\'s heart started racing, but she didn\'t want to be scared. She took a deep breath and began to climb the stairs, her eyes fixed on the door at the top.\n\nAs she reached the top, she saw a figure standing in the doorway. It was a ghostly girl, with eyes that glowed like embers and hair that flowed like the wind. Lily was frozen in terror, but the ghostly girl didn\'t seem scary at all. In fact, she looked sad and lonely.\n\n"Who are you?" Lily asked, her voice barely above a whisper.\n\n"I am Emily," the ghostly girl replied, her voice like a whisper on the wind. "I\'ve been trapped in this house for many years, waiting for someone to set me free."\n\nLily\'s fear began to fade, replaced by a sense of curiosity and compassion. She asked Emily what she needed to do to set her free, and Emily told her that she needed to find a locket that was hidden somewhere in the house.\n\nLily searched the house from top to bottom, solving puzzles and riddles along the way. Finally, she found the locket, hidden in a secret room behind a bookshelf. As she opened the locket, a bright light filled the room, and Emily\'s ghostly form began to fade.\n\n"Thank you, Lily," Emily said, her voice barely audible. "You have set me free. I can finally rest in peace."\n\nAnd with that, Emily disappeared, leaving Lily alone in the dark and dusty house. But Lily didn\'t feel scared or alone. She felt brave and proud, knowing that she had helped a lost soul find peace. From that day on, the abandoned mansion on the hill was no longer haunted, and Lily knew that she could face any challenge that came her way.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 517, 'prompt_tokens': 46, 'total_tokens': 563, 'completion_time': 1.679431514, 'prompt_time': 0.001634061, 'queue_time': 0.056346379, 'total_time': 1.6810655749999999}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_fb4860a75b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--81b0786a-8084-4f48-9028-044ad0341183-0' usage_metadata={'input_tokens': 46, 'output_tokens': 517, 'total_tokens': 563}

# %%
# chat prompt template
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
        ("system","You are a {profession} expert on {topic}"),
        ("human", "Hi {profession} expert, can you please answer a question?"),
        ("ai","sure"),
        ("human","{userinput}")
    ]
    )

messages = chat_template.format_messages(
    profession="Historian",
    topic="kennedy family",
    userinput="How many grandchildren have kenny jr"
    )

res=llm_model.invoke(messages)
print(res)
# Out:
# content="You're referring to John F. Kennedy Jr., the son of President John F. Kennedy. Unfortunately, John F. Kennedy Jr. passed away in a plane crash on July 18, 1999, at the age of 38. He was married to Carolyn Bessette-Kennedy, but they did not have any children together. Therefore, John F. Kennedy Jr. did not have any grandchildren." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 75, 'total_tokens': 160, 'completion_time': 0.216285512, 'prompt_time': 0.003620448, 'queue_time': 0.054197381, 'total_time': 0.21990596}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_fb4860a75b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--853ec626-4f20-4181-ab1a-878e0dfb5fe6-0' usage_metadata={'input_tokens': 75, 'output_tokens': 85, 'total_tokens': 160}

# %% [markdown]
# Fewshot prompting

# %%
from langchain_core.prompts import FewShotChatMessagePromptTemplate

example =[
    {"input":"hi","output":"hola"},
    {"input":"bye","output":"adios"}
]

example_prompt = ChatPromptTemplate.from_messages(
    [
        ("human","{input}"),
        ("ai","{output}")
    ]
)

few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_prompt,
    examples=example
)

final_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a professional translator to spanish"),
        few_shot_prompt,
        ("human","{input}")
    ]
)

# %% [markdown]
# Chains

# %%
chain = final_prompt | llm_model
res=chain.invoke({"input":"How are you?"})
print(res.content)
# Out:
# Estoy bien, gracias. ¿Y tú? (I'm fine, thank you. And you?)

# %% [markdown]
# Output parsers

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import SimpleJsonOutputParser

json_prompt = PromptTemplate.from_template("Return an json object with 'answer' key for the user question:{question}")

json_parser = SimpleJsonOutputParser()

chain = json_prompt | llm_model | json_parser

res = chain.invoke({"question":"what is the biggest country?"})
print(res)
# Out:
# {'answer': 'Russia'}

# %% [markdown]
# Parser using Pydantic

# %%
from pydantic import BaseModel, Field
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate

class Joke(BaseModel):
    question: str = Field(description="question to setup the joke")
    answer:str =Field(description="answer to resolve the joke")

parser = JsonOutputParser(pydantic_object=Joke)

prompt = PromptTemplate(
    template="Answer the user query. \n{query},\n{format_instructions}",
    input_variables=["query"],
    partial_variables={"format_instructions":parser.get_format_instructions()}
)

chain = prompt | llm_model | parser
res = chain.invoke({"query":"tell me a joke"})
print(res)
# Out:
# {'question': 'Why was the math book sad?', 'answer': 'Because it had too many problems'}

# %% [markdown]
# Document Loaders

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("files/test.txt")
loaded_data= loader.load()
print(loaded_data)
# Out:
# [Document(metadata={'source': 'files/test.txt'}, page_content='2025-04-04T09:53:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\nLogging Initialized for /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php  \n\n2025-04-04T09:53:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\nJob configuration settings \nSERVER_NAME=chewy--tst1.custhelp.com, (1000012)=https://hec-stg.chewy.net/services/collector/event, (1000013)=18f1b8e2-97b1-4423-b238-c035217d4e10, (1000014)=oraclecrm:dev, (1000015)=oracrm, (1000077)=105689, (1000075)=0, (1000076)=2000, (1000074)=55 \n\n2025-04-04T09:53:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\nStarting triggerJob@splunk_logger_model (Line: 2)  \n\n2025-04-04T09:53:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\ngetSplunkOutBoundData fetching 2000 SplunkOutbound records.  \n\n2025-04-04T09:53:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\nRetrieved 0 splunkOutbound records.  \n\n2025-04-04T09:53:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\nNo data returned from report   \n\n2025-04-04T09:53:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\nLoop Condition Evaluation \ntime_limit=55, start_time=1743774828, end_time=1743774828, overall_time_taken=0, moreDataFlag= \n\n2025-04-04T09:53:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\nCompleted Splunk Logging do-while Loop  \n\n2025-04-04T09:53:48-04:00 (Trace) /cgi-bin/chewy.cfg/scripts/custom/src/cron/v2/cronrunner.php@654 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\n/cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php Included  \n\n2025-04-04T09:53:48-04:00 (Notice) /cgi-bin/chewy.cfg/scripts/custom/src/cron/v2/cronrunner.php@658 4104AA2C-F56B-02F5-7DF6-DF93E6EA009B:\nCron Run Summary:  \nArray\n(\n    [success] => 1\n    [message] => Execution Completed\n    [file] => /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php\n    [executionTime] => 0.12432885169983\n)\n \n\n2025-04-04T09:54:47-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/abstract_cron_process_worker.php@2 8E5043F9-F81C-2A1B-A332-AA1A8FBC173F:\nLogging Initialized for /cgi-bin/chewy.cfg/scripts/custom/cron/abstract_cron_process_worker.php  \n\n2025-04-04T09:54:47-04:00 (Trace) /cgi-bin/chewy.cfg/scripts/custom/cron/abstract_cron_process_worker.php@2 8E5043F9-F81C-2A1B-A332-AA1A8FBC173F:\nStarting getRecords@abstract_cron_process_worker (Line: 2)  \n\n2025-04-04T09:54:47-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/abstract_cron_process_worker.php@2 8E5043F9-F81C-2A1B-A332-AA1A8FBC173F:\ngetRecords fetching 999 Rx records.  \n\n2025-04-04T09:54:47-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/abstract_cron_process_worker.php@2 8E5043F9-F81C-2A1B-A332-AA1A8FBC173F:\nRetrieved 0 Rx records.  \n\n2025-04-04T09:54:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 080F4A04-7B1D-FF34-B986-49C8BEC51038:\nLogging Initialized for /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php  \n\n2025-04-04T09:54:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 080F4A04-7B1D-FF34-B986-49C8BEC51038:\nJob configuration settings \nSERVER_NAME=chewy--tst1.custhelp.com, (1000012)=https://hec-stg.chewy.net/services/collector/event, (1000013)=18f1b8e2-97b1-4423-b238-c035217d4e10, (1000014)=oraclecrm:dev, (1000015)=oracrm, (1000077)=105689, (1000075)=0, (1000076)=2000, (1000074)=55 \n\n2025-04-04T09:54:48-04:00 (Debug) /cgi-bin/chewy.cfg/scripts/custom/cron/splunk_logger.php@2 080F4A04-7B1D-FF34-B986-49C8BEC51038 ...

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_loader = PyPDFLoader("files/test.pdf")
data = pdf_loader.load_and_split()
print(data)
print(data[0].page_content)
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2022-02-15T19:32:13+00:00', 'author': 'Katie McCray', 'moddate': '2022-02-15T19:32:13+00:00', 'source': 'files/test.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Getting Started with Data Modules Workshop \nThis document provides the preparations to get the lab environment set up and to access the \nfiles needed to proceed.  \n \n1.1 Log into the Classroom Trial Environment of Cognos Analytics on Cloud \n \nThe instructor has invited you to use an IBM Cloud “On Demand” instance of Cognos \nAnalytics. This is a real cloud instance of Cognos Analytics, the same that you can purchase \nfor your company. The other students will also be accessing this same instance as if you \neach worked for the same company. \n \nFirst, Get your student ID and Password: \n \n1. Check the private chat area of the web session. \n2. Find the student ID and Password that was issued to you by the instructor. \nIt should look similar to this:  \nExample ID: analytics.student1234@yopmail.com \nPassword: Student@123 \n \n3. If you did not receive a student ID and password, ask the instructor for one in either \nprivate or public chat areas \n \nNext, Accept the invitation to Cognos Analytics on Cloud:  \n \n1.   Open your browser (Chrome or Firefox recommended) \n2.   Go to this website: https://myibm.ibm.com \n3.   Log in with your student ID and Password'), Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2022-02-15T19:32:13+00:00', 'author': 'Katie McCray', 'moddate': '2022-02-15T19:32:13+00:00', 'source': 'files/test.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='4.   Click Accept Invitation \n \n \n \n5.   Wait 5 seconds and the Cognos Analytics on Cloud tile should appear. \n \n \n6.   Wait another 5 seconds then Click Launch \n \n \n \n \n7.   Cognos Analytics should now open. \n \nLet the instructor know if Cognos Analytics does not launch.'), Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2022-02-15T19:32:13+00:00', 'author': 'Katie McCray', 'moddate': '2022-02-15T19:32:13+00:00', 'source': 'files/test.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='1.2 Get Lab Instructions and Companion File \n \nDuring this lab, you will be instructed to upload 3 .xls files. The lab will walk you \nthrough designing a data model using Data Modules in Cognos Analytics using these \nfiles.  \n \nDownload the PDF and .xls files from the internet. \n \n1.   Open your browser (Chrome or Firefox recommended) \n2.   Download these 4 files: \n \nTIP: Save these files to a location you can remember.  \nYour browser might automatically save the files to your “Downloads” folder. \n \n\uf06f PDF Instructions: Getting Started with 11.2 Data Modules: \nhttps://public.dhe.ibm.com/software/data/sw-\nlibrary/cognos/mobile/C11/guides/CA11.2.0_Getting_Started_with_Data_Modules.pdf \n \n\uf06f XLS for upload: Customer Claim Analysis: \nhttps://community.ibm.com/accelerators/catalog/content/Customer-claim-analysis \n \n\uf06f XLS for upload: Customer Loyalty Programs: \nhttps://community.ibm.com/accelerators/catalog/content/Customer-loyalty-programs \n \n\uf06f XLS for upload: Customer Churn:        \nhttps://community.ibm.com/accelerators/catalog/content/Customer-churn \n \n \nYou will use these files later in the lab instructions.  \n \n1.3 Start the Lab \n \n__1.   Follow the instructions in the \nCA11.2.0_Getting_Started_with_Data_Modules.pdf')]
# Getting Started with Data Modules Workshop
# This document provides the preparations to get the lab environment set up and to access the
# files needed to proceed.
#
# 1.1 Log into the Classroom Trial Environment of Cognos Analytics on Cloud
#
# The instructor has invited you to use an IBM Cloud “On Demand” instance of Cognos
# Analytics. This is a real cloud instance of Cognos Analytics, the same that you can purchase
# for your company. The other students will also be accessing this same instance as if you
# each worked for the same company.
#
# First, Get your student ID and Password:
#
# 1. Check the private chat area of the web session.
# 2. Find the student ID and Password that was issued to you by the instructor.
# It should look similar to this:
# Example ID: analytics.student1234@yopmail.com
# Password: Student@123
#
# 3. If you did not receive a student ID and password, ask the instructor for one in either
# private or public chat areas
#
# Next, Accept the invitation to Cognos Analytics on Cloud:
#
# 1.   Open your browser (Chrome or Firefox recommended)
# 2.   Go to this website: https://myibm.ibm.com
# 3.   Log in with your student ID and Password

# %%
from langchain_community.document_loaders import WikipediaLoader

wiki = WikipediaLoader(query="Tesla", load_max_docs=1)
data = wiki.load()
print(data)
# Out:
# [Document(metadata={'title': 'Tesla Cybertruck', 'summary': 'The Tesla Cybertruck is a battery-electric full-size pickup truck manufactured by Tesla, Inc. since 2023. It was first unveiled as a prototype in November 2019, featuring a distinctive angular design composed of flat, unpainted stainless steel body panels, drawing comparisons to low-polygon computer models.\nOriginally scheduled for production in late 2021, the vehicle faced multiple delays before entering limited production at Gigafactory Texas in November 2023, with initial customer deliveries occurring later that month. As of 2025, three variants are available: a tri-motor all-wheel drive (AWD) model marketed as the "Cyberbeast", a dual-motor AWD model, and a single-motor rear-wheel drive (RWD) "Long Range" model. EPA range estimates vary by configuration, from 320 to 350 miles (515 to 565 km). \nAs of 2025, the Cybertruck is sold in the United States, Mexico, Canada and South Korea. The Cybertruck has been criticized for its production quality and safety concerns while its sales have been described as disappointing.', 'source': 'https://en.wikipedia.org/wiki/Tesla_Cybertruck'}, page_content='The Tesla Cybertruck is a battery-electric full-size pickup truck manufactured by Tesla, Inc. since 2023. It was first unveiled as a prototype in November 2019, featuring a distinctive angular design composed of flat, unpainted stainless steel body panels, drawing comparisons to low-polygon computer models.\nOriginally scheduled for production in late 2021, the vehicle faced multiple delays before entering limited production at Gigafactory Texas in November 2023, with initial customer deliveries occurring later that month. As of 2025, three variants are available: a tri-motor all-wheel drive (AWD) model marketed as the "Cyberbeast", a dual-motor AWD model, and a single-motor rear-wheel drive (RWD) "Long Range" model. EPA range estimates vary by configuration, from 320 to 350 miles (515 to 565 km). \nAs of 2025, the Cybertruck is sold in the United States, Mexico, Canada and South Korea. The Cybertruck has been criticized for its production quality and safety concerns while its sales have been described as disappointing.\n\n\n== History ==\n\n\n=== Background ===\nTesla CEO Elon Musk\'s ideas for a pickup truck were first stated publicly in 2012 and 2013, envisioning to build a "Tesla supertruck with crazy torque, dynamic air suspension, and corners like it\'s on rails". In early 2014 Musk predicted 4–5 years before work could start on the product, then in a 2015 interview with CNN, Musk stated that the Tesla pickup would be the equivalent of a Ford F-150. In mid-2016, the outline for a consumer pickup truck was included in part 2 of the Tesla Master Plan. Musk suggested that the same chassis could be used for a van and a pickup truck. In 2017, Musk teased the picture of a "pickup truck that can carry a pickup truck" was displayed at the official reveal for the Tesla Semi and Roadster.\nIn March 2019, following the Tesla Model Y launch, Musk distributed a teaser image of a vehicle described as having a cyberpunk or Blade Runner style, with the form resembling a futuristic armored personnel carrier. It was rumored to be named the Model B. On November 6, 2019, Tesla filed for a trademark on "Cybrtrk", which was granted by the United States Patent and Trademark Office but was later abandoned on August 10, 2020.\n\n\n=== 2019 concept ===\n\nA concept Cybertruck was unveiled in Los Angeles, California, on November 21, 2019—the same month, year, and location in which the movie Blade Runner was set. The Cybertruck was launched under a graffiti-themed "Cybertruck" logo.\nDuring the unveiling, Tesla claimed that the Cybertruck\'s "Armor Glass" windows were virtually unbreakable, but two windows shattered when Franz von Holzhausen threw a metal ball at each of them. Musk later claimed that the windows were damaged because, in an earlier demonstration, the door had been hit by a sledgeha ...

# %%
from langchain_core.prompts import ChatPromptTemplate



chat_prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "Answer the {question} for the given context: {context}" )
    ]
)

messages = chat_prompt.format_messages(
    question="what is Tesla?",
    context=data
)

res = llm_model.invoke(messages)
print(res)
# Out:
# content='In the context of the provided text, Tesla refers to Tesla, Inc., an American electric vehicle and clean energy company founded by Elon Musk. Specifically, it is the manufacturer of the Tesla Cybertruck, a battery-electric full-size pickup truck that is the main subject of the document.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 1227, 'total_tokens': 1285, 'completion_time': 0.166485451, 'prompt_time': 0.0624144, 'queue_time': 0.058286379, 'total_time': 0.228899851}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_fb4860a75b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--a3aa803f-a8ef-4fb7-8df1-e59d7a73c578-0' usage_metadata={'input_tokens': 1227, 'output_tokens': 58, 'total_tokens': 1285}

# %% [markdown]
# CharacterTextSplitter

# %%
from langchain_text_splitters import CharacterTextSplitter

splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len,
    is_separator_regex=False
)

texts = splitter.create_documents([data[0].metadata['summary']])
print(texts)
print(texts[0])
print(texts[1])
# Out:
# [Document(metadata={}, page_content='The Tesla Cybertruck is a battery-electric full-size pickup truck manufactured by Tesla, Inc. since 2023. It was first unveiled as a prototype in November 2019, featuring a distinctive angular design composed of flat, unpainted stainless steel body panels, drawing comparisons to low-polygon computer models.\nOriginally scheduled for production in late 2021, the vehicle faced multiple delays before entering limited production at Gigafactory Texas in November 2023, with initial customer deliveries occurring later that month. As of 2025, three variants are available: a tri-motor all-wheel drive (AWD) model marketed as the "Cyberbeast", a dual-motor AWD model, and a single-motor rear-wheel drive (RWD) "Long Range" model. EPA range estimates vary by configuration, from 320 to 350 miles (515 to 565 km). \nAs of 2025, the Cybertruck is sold in the United States, Mexico, Canada and South Korea'), Document(metadata={}, page_content='EPA range estimates vary by configuration, from 320 to 350 miles (515 to 565 km). \nAs of 2025, the Cybertruck is sold in the United States, Mexico, Canada and South Korea. The Cybertruck has been criticized for its production quality and safety concerns while its sales have been described as disappointing')]
# page_content='The Tesla Cybertruck is a battery-electric full-size pickup truck manufactured by Tesla, Inc. since 2023. It was first unveiled as a prototype in November 2019, featuring a distinctive angular design composed of flat, unpainted stainless steel body panels, drawing comparisons to low-polygon computer models.
# Originally scheduled for production in late 2021, the vehicle faced multiple delays before entering limited production at Gigafactory Texas in November 2023, with initial customer deliveries occurring later that month. As of 2025, three variants are available: a tri-motor all-wheel drive (AWD) model marketed as the "Cyberbeast", a dual-motor AWD model, and a single-motor rear-wheel drive (RWD) "Long Range" model. EPA range estimates vary by configuration, from 320 to 350 miles (515 to 565 km).
# As of 2025, the Cybertruck is sold in the United States, Mexico, Canada and South Korea'
# page_content='EPA range estimates vary by configuration, from 320 to 350 miles (515 to 565 km).
# As of 2025, the Cybertruck is sold in the United States, Mexico, Canada and South Korea. The Cybertruck has been criticized for its production quality and safety concerns while its sales have been described as disappointing'

# %% [markdown]
# Recursive Character text splitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter  = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

texts = splitter.create_documents([data[0].metadata['summary']])
print(texts)
print(len(texts))
# Out:
# [Document(metadata={}, page_content='The Tesla Cybertruck is a battery-electric full-size pickup truck manufactured by Tesla, Inc. since 2023. It was first unveiled as a prototype in November 2019, featuring a distinctive angular design composed of flat, unpainted stainless steel body panels, drawing comparisons to low-polygon computer models.\nOriginally scheduled for production in late 2021, the vehicle faced multiple delays before entering limited production at Gigafactory Texas in November 2023, with initial customer deliveries occurring later that month. As of 2025, three variants are available: a tri-motor all-wheel drive (AWD) model marketed as the "Cyberbeast", a dual-motor AWD model, and a single-motor rear-wheel drive (RWD) "Long Range" model. EPA range estimates vary by configuration, from 320 to 350 miles (515 to 565 km).'), Document(metadata={}, page_content='As of 2025, the Cybertruck is sold in the United States, Mexico, Canada and South Korea. The Cybertruck has been criticized for its production quality and safety concerns while its sales have been described as disappointing.')]
# 2
